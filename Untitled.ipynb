# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('epl-allseasons-matchstats.csv')

# %%
df.head(5)
# Out:
#     Season        Date        Referee     HomeTeam    AwayTeam FullTime  \
# 0  2010/11  2010-08-14         M Dean  Aston Villa    West Ham  HomeWin
# 1  2010/11  2010-08-14         P Dowd    Blackburn     Everton  HomeWin
# 2  2010/11  2010-08-14      S Attwell       Bolton      Fulham     Draw
# 3  2010/11  2010-08-14  M Clattenburg      Chelsea   West Brom  HomeWin
# 4  2010/11  2010-08-14       A Taylor   Sunderland  Birmingham     Draw
#
#   Halftime  HomeGoals  HomeGoalsHalftime  HomeShots  ...  HomeYellowCards  \
# 0  HomeWin          3                  2         23  ...                1
# 1  HomeWin          1                  1          7  ...                2
# 2     Draw          0                  0         13  ...                1
# 3  HomeWin          6                  2         18  ...                1
# 4  HomeWin          2                  1          6  ...                3
#
#    HomeRedCards  AwayGoals  AwayGoalsHalftime  AwayShots  AwayShotsOnTarget  \
# 0             0          0                  0         12                  2
# 1             0          0                  0         17                 12
# 2             0          0                  0         12                  7
# 3             0          0                  0         10                  4
# 4             1          2                  0         13                  7
#
#    AwayCorners  AwayFouls  AwayYellowCards  AwayRedCards
# 0            7         15                2             0
# 1            3         14                1             0
# 2            8         13                3             0
# 3            1         10                0             0
# 4            6         10                3             0
#
# [5 rows x 23 columns]

# %%
print(df.dtypes)
# Out:
# Season               object
# Date                 object
# Referee              object
# HomeTeam             object
# AwayTeam             object
# FullTime             object
# Halftime             object
# HomeGoals             int64
# HomeGoalsHalftime     int64
# HomeShots             int64
# HomeShotsOnTarget     int64
# HomeCorners           int64
# HomeFouls             int64
# HomeYellowCards       int64
# HomeRedCards          int64
# AwayGoals             int64
# AwayGoalsHalftime     int64
# AwayShots             int64
# AwayShotsOnTarget     int64
# AwayCorners           int64
# AwayFouls             int64
# AwayYellowCards       int64
# AwayRedCards          int64
# dtype: object

# %%
df['Referee'].value_counts()
# Out:
# Referee
# M Dean           288
# M Atkinson       281
# M Oliver         266
# A Taylor         256
# A Marriner       249
# J Moss           225
# K Friend         216
# L Mason          215
# M Clattenburg    175
# M Jones          170
# C Pawson         157
# L Probert        137
# N Swarbrick      132
# P Dowd           130
# H Webb           119
# C Foy            109
# S Attwell         95
# R Madley          91
# R East            91
# P Tierney         80
# G Scott           68
# C Kavanagh        66
# M Halsey          60
# P Walton          42
# D Coote           28
# S Hooper          21
# A Madley          13
# P Bankes          11
# K Stroud           3
# l Mason            1
# O Langford         1
# T Robinson         1
# R Jones            1
# S Scott            1
# D England          1
# Name: count, dtype: int64

# %%
df['Referee'].value_counts()
# Out:
# Referee
# M Dean           288
# M Atkinson       281
# M Oliver         266
# A Taylor         256
# A Marriner       249
# J Moss           225
# K Friend         216
# L Mason          215
# M Clattenburg    175
# M Jones          170
# C Pawson         157
# L Probert        137
# N Swarbrick      132
# P Dowd           130
# H Webb           119
# C Foy            109
# S Attwell         95
# R Madley          91
# R East            91
# P Tierney         80
# G Scott           68
# C Kavanagh        66
# M Halsey          60
# P Walton          42
# D Coote           28
# S Hooper          21
# A Madley          13
# P Bankes          11
# K Stroud           3
# l Mason            1
# O Langford         1
# T Robinson         1
# R Jones            1
# S Scott            1
# D England          1
# Name: count, dtype: int64

# %%
df['Halftime'].value_counts()
# Out:
# Halftime
# Draw       1558
# HomeWin    1307
# AwayWin     935
# Name: count, dtype: int64

# %%
df['FullTime'].value_counts()
# Out:
# FullTime
# HomeWin    1737
# AwayWin    1127
# Draw        936
# Name: count, dtype: int64

# %%
import scipy.stats as ss

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# %%
HT_FT = cramers_v(df['FullTime'], df['Halftime'])

# %%
HT_FT
# Out:
# np.float64(0.46167787672161076)

# %%
import seaborn as sns

# %%
df[df['Halftime']!=df['FullTime']]
# Out:
#        Season        Date     Referee        HomeTeam          AwayTeam  \
# 4     2010/11  2010-08-14    A Taylor      Sunderland        Birmingham
# 11    2010/11  2010-08-21    M Oliver      Birmingham         Blackburn
# 12    2010/11  2010-08-21     L Mason         Everton            Wolves
# 14    2010/11  2010-08-21    K Friend       West Brom        Sunderland
# 15    2010/11  2010-08-21  A Marriner        West Ham            Bolton
# ...       ...         ...         ...             ...               ...
# 3791  2019/20  2020-07-26      J Moss         Burnley          Brighton
# 3793  2019/20  2020-07-26  A Marriner  Crystal Palace         Tottenham
# 3795  2019/20  2020-07-26  M Atkinson       Leicester        Man United
# 3797  2019/20  2020-07-26    A Taylor       Newcastle         Liverpool
# 3798  2019/20  2020-07-26    P Bankes     Southampton  Sheffield United
#
#      FullTime Halftime  HomeGoals  HomeGoalsHalftime  HomeShots  ...  \
# 4        Draw  HomeWin          2                  1          6  ...
# 11    HomeWin     Draw          2                  0         10  ...
# 12       Draw  HomeWin          1                  1         14  ...
# 14    HomeWin     Draw          1                  0         11  ...
# 15    AwayWin     Draw          1                  0         17  ...
# ...       ...      ...        ...                ...        ...  ...
# 3791  AwayWin     Draw          1                  1         13  ...
# 3793     Draw  AwayWin          1                  0         13  ...
# 3795  AwayWin     Draw          0                  0         14  ...
# 3797  AwayWin     Draw          1                  1          3  ...
# 3798  HomeWin  AwayWin          3                  0         13  ...
#
#       HomeYellowCards  HomeRedCards  AwayGoals  AwayGoalsHalftime  AwayShots  \
# 4                   3             1          2                  0         13
# 11                  2             0          1                  0          7
# 12                  1             0          1                  0          9
# 14                  2             0          0                  0         10
# 15                  2             0          3                  0         12
# ...               ...           ...        ...                ...        ...
# 3791                3             0          2                  1         14
# 3793                3             0          1                  1          7
# 3795                1             1          2                  0          7
# 3797                1             0          3                  1         14
# 3798                0             0          1                  1          5
#
#       AwayShotsOnTarget  AwayCorners  AwayFouls  AwayYellowCards  AwayRedCards
# 4                     7            6         10                3             0
# 11                    2           12         14                3             0
# 12                    4            3         15                2             0
# 14                    4            6         12                2             0
# 15                    8            5         18                4             0
# ...                 ...          ...        ...              ...           ...
# 3791                  4            7         11                0             0
# 3793                  2            2         13                2             0
# 3795                  3            3         11                4             0
# 3797                  6            4          5                0             0
# 3798                  3            1         16                1             0
#
# [1502 rows x 23 columns]

# %%
df['AwayRedCards'].value_counts()
# Out:
# AwayRedCards
# 0    3502
# 1     287
# 2      11
# Name: count, dtype: int64

# %%
df['HomeGoals'].value_counts()
# Out:
# HomeGoals
# 1    1220
# 2     944
# 0     854
# 3     485
# 4     194
# 5      71
# 6      23
# 7       5
# 8       4
# Name: count, dtype: int64

# %%
df_down = df[['AwayRedCards', 'HomeGoals']]

# %%
df_down.head()
# Out:
#    AwayRedCards  HomeGoals
# 0             0          3
# 1             0          1
# 2             0          0
# 3             0          6
# 4             0          2

# %%
df_down.corr()
# Out:
#               AwayRedCards  HomeGoals
# AwayRedCards      1.000000   0.071635
# HomeGoals         0.071635   1.000000

# %%
sns.heatmap(df_down.corr(), annot = True)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#          HomeGoals  HomeGoalsHalftime    HomeShots  HomeShotsOnTarget  \
# count  3800.000000        3800.000000  3800.000000        3800.000000
# mean      1.552368           0.687105    14.141316           5.697632
# std       1.299116           0.844749     5.522862           3.317283
# min       0.000000           0.000000     0.000000           0.000000
# 25%       1.000000           0.000000    10.000000           3.000000
# 50%       1.000000           0.000000    14.000000           5.000000
# 75%       2.000000           1.000000    17.000000           8.000000
# max       8.000000           5.000000    43.000000          24.000000
#
#        HomeCorners    HomeFouls  HomeYellowCards  HomeRedCards    AwayGoals  \
# count  3800.000000  3800.000000      3800.000000   3800.000000  3800.000000
# mean      5.984474    10.503158         1.498684      0.059211     1.193158
# std       3.142994     3.380960         1.205846      0.243730     1.167948
# min       0.000000     0.000000         0.000000      0.000000     0.000000
# 25%       4.000000     8.000000         1.000000      0.000000     0.000000
# 50%       6.000000    10.000000         1.000000      0.000000     1.000000
# 75%       8.000000    13.000000         2.000000      0.000000     2.000000
# max      19.000000    24.000000         7.000000      2.000000     9.000000
#
#        AwayGoalsHalftime    AwayShots  AwayShotsOnTarget  AwayCorners  \
# count        3800.000000  3800.000000        3800.000000  3800.000000
# mean            0.530263    11.297632           4.570789     4.770000
# std             0.741455     4.760613           2.806423     2.744684
# min             0.000000     0.000000           0.000000     0.000000
# 25%             0.000000     8.000000           3.000000     3.000000
# 50%             0.000000    11.000000           4.000000     4.000000
# 75%             1.000000    14.000000           6.000000     6.000000
# max             5.000000    30.000000          20.000000    19.000000
#
#          AwayFouls  AwayYellowCards  AwayRedCards
# count  3800.000000      3800.000000   3800.000000
# mean     10.976579         1.760789      0.081316
# std       3.530819         1.273741      0.283750
# min       1.000000         0.000000      0.000000
# 25%       9.000000         1.000000      0.000000
# 50%      11.000000         2.000000      0.000000
# 75%      13.000000         3.000000      0.000000
# max      26.000000         9.000000      2.000000
